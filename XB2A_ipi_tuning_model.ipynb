# %%
# %matplotlib inline
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.io import loadmat

from aux import loadmat_h5
from disp import set_font_size

TUNING_FILE = 'data/simple/ipi_freq_timecourses.npy'
CELL_FILE = 'data/christa/VLP_knownAUD_neurons_copiedFromFlyWireDatabase_20200617.xlsx'
# W_FILE = 'data/christa/allAudNeurons_connMat_noDupSyn.mat'
W_FILE = 'data/christa/allAudNeurons_connMat_noDupSyn_cleftFilt_20210603.mat'

FPS = 8.5

# %%
tuning_data = np.load(TUNING_FILE, allow_pickle=True)[0]

ipi = tuning_data['ipi']
ipi_rsps = tuning_data['ipi_rsps_means']

freq = tuning_data['freq']
freq_rsps = tuning_data['freq_rsps_means']

# %%
cell_df = pd.read_excel(CELL_FILE, engine='openpyxl')
cell_df[['short name', 'lineID for IPI/Freq tuning curves', 'Eckstein NT classification numeric']]
# Out:
#          short name  lineID for IPI/Freq tuning curves  \
# 0             A1_L1                                NaN
# 1             A1_L2                                NaN
# 2             A1_L3                                NaN
# 3             A1_R1                                NaN
# 4             A1_R2                                NaN
# ..              ...                                ...
# 493        pC1as_R1                                NaN
# 494        pC1as_R2                                NaN
# 495             NaN                                NaN
# 496             NaN                                NaN
# 497  16374-27885_L8                                NaN
#
#      Eckstein NT classification numeric
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 493                                 1.0
# 494                                 1.0
# 495                                 NaN
# 496                                 NaN
# 497                                -1.0
#
# [498 rows x 3 columns]

# %%
for cell_line, sign in zip(cell_df['short name'], cell_df['Eckstein NT classification numeric']):
    print(cell_line, sign)
# Out:
# A1_L1 nan
# A1_L2 nan
# A1_L3 nan
# A1_R1 nan
# A1_R2 nan
# A2_L 1.0
# A2_R 1.0
# B1-1_L1 1.0
# B1-1_L2 1.0
# B1-1_L3 1.0
# B1-1_L4 1.0
# B1-1_L5 1.0
# B1-1_L6 1.0
# B1-1_R1 1.0
# B1-1_R2 1.0
# B1-1_R3 1.0
# B1-1_R4 1.0
# B1-1_R5 1.0
# B1-1_R6 1.0
# B1-2_L1 1.0
# B1-2_L2 1.0
# B1-2_L3 1.0
# B1-2_L4 1.0
# B1-2_L5 1.0
# B1-2_L6 1.0
# B1-2_L7 1.0
# B1-2_L8 1.0
# B1-2_L9 1.0
# B1-2_R1 1.0
# B1-2_R2 1.0
# B1-2_R3 1.0
# B1-2_R4 1.0
# B1-2_R5 1.0
# B1-2_R6 1.0
# B1-2_R7 1.0
# B1-2_R8 1.0
# B1-3_L1 1.0
# B1-3_L2 1.0
# B1-3_L3 1.0
# B1-3_L4 1.0
# B1-3_L5 1.0
# B1-3_R1 1.0
# B1-3_R2 1.0
# B1-3_R3 1.0
# B1-3_R4 1.0
# B1-3_R5 1.0
# B1-4_L1 1.0
# B1-4_L2 1.0
# B1-4_L3 1.0
# B1-4_L4 1.0
# B1-4_L5 1.0
# B1-4_L6 1.0
# B1-4_L7 1.0
# B1-4_L8 1.0
# B1-4_L9 1.0
# B1-4_R1 1.0
# B1-4_R2 1.0
# B1-4_R3 1.0
# B1-4_R4 1.0
# B1-4_R5 1.0
# B1-4_R6 1.0
# B1-4_R7 1.0
# B1-4_R8 1.0
# B1-u_L1 1.0
# B1-u_L2 1.0
# B1-u_L3 1.0
# B1-u_L4 1.0
# B1-u_L5 1.0
# B1-u_L6 1.0
# B1-u_L7 1.0
# B1-u_L8 1.0
# B1-u_L9 1.0
# B1-u_L10 1.0
# B1-u_L11 1.0
# B1-u_L12 1.0
# B1-u_L13 1.0
# B1-u_L14 1.0
# B1-u_L15 1.0
# B1-u_L16 1.0
# B1-u_L17 1.0
# B1-u_L18 1.0
# B1-u_L19 1.0
# B1-u_L20 1.0
# B1-u_L21 1.0
# B1-u_L22 1.0
# B1-u_L23 1.0
# B1-u_L24 1.0
# B1-u_L25 1.0
# B1-u_L26 1.0
# B1-u_L27 1.0
# B1-u_L28 1.0
# B1-u_L29 1.0
# B1-u_L30 1.0
# B1-u_L31 1.0
# B1-u_L32 1.0
# B1-u_R1 1.0
# B1-u_R2 1.0
# B1-u_R3 1.0
# B1-u_R4 1.0
# B1-u_R5 1.0
# B1-u_R6 1.0
# B1-u_R7 1.0
# B1-u_R8 1.0
# B1-u_R9 1.0
# B1-u_R10 1.0
# B1-u_R11 1.0
# B1-u_R12 1.0
# B1-u_R13 1.0
# B1-u_R14 1.0
# B1-u_R15 1.0
# B1-u_R16 1.0
# B1-u_R17 1.0
# B1-u_R18 1.0
# B1-u_R19 1.0
# B1-u_R20 1.0
# B1-u_R21 1.0
# B1-u_R22 1.0
# B1-u_R23 1.0
# B1-u_R24 1.0
# B1-u_R25 1.0
# B1-u_R26 1.0
# B1-u_R27 1.0
# B1-u_R28 1.0
# B1-u_R29 1.0
# B1-u_R30 1.0
# B1-u_R31 1.0
# B2_L1 -1.0
# B2_L2 -1.0
# B2_L3 -1.0
# B2_R1 -1.0
# B2_R2 -1.0
# B2_R3 -1.0
# GF_L 1.0
# GF_R 1.0
# WED-VLP-1_L1 1.0
# WED-VLP-1_L2 1.0
# WED-VLP-1_L3 1.0
# WED-VLP-1_L4 1.0
# WED-VLP-1_L5 1.0
# WED-VLP-1_L6 1.0
# WED-VLP-1_L7 1.0
# WED-VLP-1_L8 1.0
# WED-VLP-1_R1 1.0
# WED-VLP-1_R2 1.0
# WED-VLP-1_R3 1.0
# WED-VLP-1_R4 1.0
# WED-VLP-1_R5 1.0
# WED-VLP-1_R6 1.0
# WED-VLP-1_R7 1.0
# WED-VLP-1_R8 1.0
# WED-VLP-2_L1 1.0
# WED-VLP-2_L2 1.0
# WED-VLP-2_L3 1.0
# WED-VLP-2_L4 1.0
# WED-VLP-2_L5 1.0
# WED-VLP-2_L6 1.0
# WED-VLP-2_L7 1.0
# WED-VLP-2_R1 1.0
# WED-VLP-2_R2 1.0
# WED-VLP-2_R3 1.0
# WED-VLP-2_R4 1.0
# WED-VLP-2_R5 1.0
# WV-WV-1_1 -1.0
# WV-WV-1_2 -1.0
# WV-WV-1_3 -1.0
# WV-WV-2_1 -1.0
# WV-WV-2_2 -1.0
# WV-WV-2_3 -1.0
# WV-WV-2_4 -1.0
# WV-WV-2_5 -1.0
# WV-WV-2_6 -1.0
# WV-WV-3_1 -1.0
# WV-WV-3_2 -1.0
# WV-WV-3_3 -1.0
# WV-WV-3_4 -1.0
# WV-WV-3_5 -1.0
# WV-WV-3_6 -1.0
# WV-WV-3_7 -1.0
# WV-WV-3_8 -1.0
# WV-WV-3_9 -1.0
# 16374-27885_L1 -1.0
# 16374-27885_L2 -1.0
# 16374-27885_L3 -1.0
# 16374-27885_L4 -1.0
# 16374-27885_L5 -1.0
# 16374-27885_L6 -1.0
# 16374-27885_L7 -1.0
# 16374-27885_Lb1 -1.0
# 16374-27885_Lb2 -1.0
# 16374-27885_R1 -1.0
# 16374-27885_R2 -1.0
# 16374-27885_R3 -1.0
# 16374-27885_R4 -1.0
# 16374-27885_R5 -1.0
# 16374-27885_R6 -1.0
# 16374-27885_R7 -1.0
# 16374-27885_R8 -1.0
# 16374-27885_Rb1 -1.0
# 16374-27885_Rb2 -1.0
# 27885_Lcom1 -1.0
# 27885_Lcom2 -1.0
# 27885_Lcom3 -1.0
# 27885_Rcom1 -1.0
# 27885_Rcom2 -1.0
# 27885_Rcom3 -1.0
# 27936_L1 1.0
# 27936_L2 1.0
# 27936_L3 1.0
# 27936_L4 1.0
# 27936_L5 1.0
# 27936_L6 1.0
# 27936_R1 1.0
# 27936_R2 1.0
# 27936_R3 1.0
# 27936_R4 1.0
# 27936_R5 1.0
# 36007_L1 -1.0
# 36007_L2 -1.0
# 36007_L3 -1.0
# 36007_R1 -1.0
# 36007_R2 -1.0
# 36007_R3 -1.0
# 36007_R4 -1.0
# 36007_R5 -1.0
# 36007_R6 -1.0
# 37007_L1 1.0
# 37007_L2 1.0
# 37007_L3 1.0
# 37007_L4 1.0
# 37007_L5 1.0
# 37007_L6 1.0
# 37007_L7 1.0
# 37007_L8 1.0
# 37007_L9 1.0
# 37007_L10 1.0
# 37007_L11 1.0
# 37007_L12 1.0
# 37007_L13 1.0
# 37007_L14 1.0
# 37007_L15 1.0
# 37007_L16 1.0
# 37007_R1 1.0
# 37007_R2 1.0
# 37007_R3 1.0
# 37007_R4 1.0
# 37007_R5 1.0
# 37007_R6 1.0
# 37007_R7 1.0
# 37007_R8 1.0
# 37007_R9 1.0
# 37007_R10 1.0
# 40303_L1 -1.0
# 40303_L2 -1.0
# 40303_L3 -1.0
# 40303_L4 -1.0
# 40303_L5 -1.0
# 40303_L6 -1.0
# 40303_L7 -1.0
# 40303_R1 -1.0
# 40303_R3 -1.0
# 40303_R4 -1.0
# 40303_R5 -1.0
# 40303_R6 -1.0
# 40303_R7 -1.0
# 41728-41730_L1 1.0
# 41728-41730_L2 1.0
# 41728-41730_L3 1.0
# 41728-41730_L4 1.0
# 41728-41730_L5 1.0
# 41728-41730_L6 1.0
# 41728-41730_R1 1.0
# 41728-41730_R2 1.0
# 41728-41730_R3 1.0
# 41728-41730_R4 1.0
# 41728-41730_R5 1.0
# 41728-41730_R6 1.0
# 41728-41730_R7 1.0
# 41728-41730_R8 1.0
# 41730_R1 1.0
# 41730_R2 1.0
# 41730_R3 1.0
# 43299_L1 -1.0
# 43299_L2 -1.0
# 43299_L3 -1.0
# 43299_L4 -1.0
# 43299_R1 -1.0
# 43299_R2 -1.0
# 43299_R3 -1.0
# 43299_R4 -1.0
# 43299_R5 -1.0
# 43299_R6 -1.0
# 43299_R7 -1.0
# 43299_R8 -1.0
# 43299_R9 -1.0
# 43299_R10 -1.0
# 21914_L1 10.0
# 21914_L2 nan
# 21914_R1 10.0
# 21914_R2 nan
# 29146_L1 1.0
# 29146_L2 1.0
# 29146_L3 1.0
# 29146_L4 1.0
# 29146_L5 1.0
# 29146_L6 1.0
# 29146_R1 1.0
# 29146_R2 1.0
# 29146_R3 1.0
# 29146_R4 1.0
# 29146_R5 1.0
# 29146_R6 1.0
# 29146_R7 1.0
# 35996_L 1.0
# 35996_R1 1.0
# 35996_R2 1.0
# 35996_R3 1.0
# 35996_R4 1.0
# 35996_R5 1.0
# 35996_R6 1.0
# 35996_R7 1.0
# 35996_R8 1.0
# 47261_L1 1.0
# 47261_L2 1.0
# 47261_L3 1.0
# 47261_L4 1.0
# 47261_L5 1.0
# 47261_L6 1.0
# 47261_L7 1.0
# 47261_L8 1.0
# 47261_L9 1.0
# 47261_L10 1.0
# 47261_R1 1.0
# 47261_R2 1.0
# 47261_R3 1.0
# 47261_R4 1.0
# 47261_R5 1.0
# 47261_R6 1.0
# 23281_L1 -1.0
# 23281_L2 -1.0
# 23281_L3 -1.0
# 23281_L4 -1.0
# 23281_L5 -1.0
# 23281_L6 -1.0
# 23281_L7 -1.0
# 23281_L8 -1.0
# 23281_L9 -1.0
# 23281_L10 -1.0
# 23281_L11 -1.0
# 23281_R1 -1.0
# 23281_R2 -1.0
# 23281_R3 -1.0
# 23281_R4 -1.0
# 23281_R5 -1.0
# 23281_R6 -1.0
# 23281_R7 -1.0
# 23281_R8 -1.0
# 23281_R9 -1.0
# 23281_R10 -1.0
# 23281_R11 -1.0
# 23281_R12 -1.0
# 23281_R13 -1.0
# 23281_R14 -1.0
# 27932_L1 -1.0
# 27932_L2 -1.0
# 27932_L3 -1.0
# 27932_L4 -1.0
# 27932_L5 -1.0
# 27932_R1 -1.0
# 27932_R2 -1.0
# 27932_R3 -1.0
# 27932_R4 -1.0
# 29136_L1 1.0
# 29136_L2 1.0
# 29136_L3 1.0
# 29136_L4 1.0
# 29136_L5 1.0
# 29136_L6 1.0
# 29136_R1 1.0
# 29136_R2 1.0
# 29136_R3 1.0
# 29136_R4 1.0
# 29136_R5 1.0
# 29136_R6 1.0
# 29136_R7 1.0
# 29136_R8 1.0
# 29136_R9 1.0
# 35916_L1 -1.0
# 35916_L2 -1.0
# 35916_L3 -1.0
# 35916_L4 -1.0
# 35916_L5 -1.0
# 35916_L6 -1.0
# 35916_R1 -1.0
# 35916_R2 -1.0
# 35916_R5 -1.0
# 35916_R6 -1.0
# 35916_R7 -1.0
# 35916_R8 -1.0
# 35916_R9 -1.0
# 35916_R10 -1.0
# 35916_R11 -1.0
# 35916_R12 -1.0
# 35916_R13 -1.0
# 35916_R14 -1.0
# 35916_R15 -1.0
# 36012_L -1.0
# 36012_R -1.0
# 38918_L -1.0
# 38918_R -1.0
# 40316_La1 -1.0
# 40316_La2 -1.0
# 40316_La3 -1.0
# 40316_La4 -1.0
# 40316_La5 -1.0
# 40316_La6 -1.0
# 40316_La7 -1.0
# 40316_Lb1 -1.0
# 40316_Lb2 -1.0
# 40316_Ra1 -1.0
# 40316_Ra2 -1.0
# 40316_Ra3 -1.0
# 40316_Ra4 -1.0
# 40316_Ra5 -1.0
# 40316_Ra6 -1.0
# 40316_Ra7 -1.0
# 40316_Rb1 -1.0
# 40316_Rb2 -1.0
# 41739_L nan
# 41739_R nan
# 45858_L -1.0
# 45858_R -1.0
# vpoEN_L1 1.0
# vpoEN_L2 1.0
# vpoEN_R1 1.0
# vpoEN_R2 1.0
# vpoIN_L1 -1.0
# vpoIN_L2 -1.0
# vpoIN_L3 -1.0
# vpoIN_L4 -1.0
# vpoIN_L5 -1.0
# vpoIN_L6 -1.0
# vpoIN_L7 -1.0
# vpoIN_L8 -1.0
# vpoIN_R1 -1.0
# vpoIN_R2 -1.0
# vpoIN_R3 -1.0
# vpoIN_R4 -1.0
# vpoIN_R5 -1.0
# vpoIN_R6 -1.0
# pMN1_L 1.0
# pMN2_L 1.0
# pMN2_R 1.0
# pC2la_L1 1.0
# pC2la_L2 1.0
# pC2la_L3 1.0
# pC2la_L4 1.0
# pC2la_L5 1.0
# pC2la_L6 1.0
# pC2la_L7 1.0
# pC2la_R1 1.0
# pC2la_R2 1.0
# pC2la_R3 1.0
# pC2la_R4 1.0
# pC2lb_L1 1.0
# pC2lb_L2 1.0
# pC2lb_L3 1.0
# pC2lb_L4 1.0
# pC2lb_R1 1.0
# pC2lb_R2 1.0
# pC2lb_R3 1.0
# pC2lb_R4 1.0
# pC2lb_R5 1.0
# pC2lc_R1 1.0
# pC2lc_R2 1.0
# pC2lc_R3 1.0
# pC2ld_R 1.0
# pC2med_L1 1.0
# pC2med_L2 1.0
# pC2med_L3 1.0
# pC2med_L4 1.0
# pC2med_L5 1.0
# pC2med_L6 1.0
# pC2med_L7 1.0
# pC2med_L8 1.0
# pC2med_R1 1.0
# pC2med_R2 1.0
# pC2med_R3 1.0
# pC2med_R4 1.0
# pC2med_R5 1.0
# pC2med_R6 1.0
# pC1al_L 1.0
# pC1al_R 1.0
# pC1as_L 1.0
# pC1as_R1 1.0
# pC1as_R2 1.0
# nan nan
# nan nan
# 16374-27885_L8 -1.0

# %%
labels = np.array(cell_df['short name'])
line_ids = np.array(cell_df['lineID for IPI/Freq tuning curves'])  # floats/ints from 1 to 30 inclusive
signs = np.array(cell_df['Eckstein NT classification numeric'])

label2line = {label: line_id for label, line_id in zip(labels, line_ids)}
label2sign = {label: np.sign(sign) for label, sign in zip(labels, signs)}

# %%
w_th = 1

w_data = loadmat_h5(W_FILE)
labels_w = w_data['neuronNames'][:, 0]  # all labels with a row in the connectivity matrix

w_raw = w_data['cxns_noDup']
w = w_raw.copy()
w[w_raw < w_th] = 0
w[np.isnan(w)] = 0

# add sign
sign_mat = np.zeros(w.shape)  # note this zeroes any weights without signs attached
for cl, label in enumerate(labels_w):
    if label in label2sign and not np.isnan(label2sign[label]):
        sign_mat[cl, :] = label2sign[label]
            
w = w*sign_mat  # multiply w by signs

# %%
for label in labels_w:  # fill any missing labels with nan
    if label not in label2line:
        label2line[label] = np.nan

# %% [markdown]
# How to get tuning curves idx associated w/ row i in w:
#
# 1. Get i'th label from label_w.
# 2. Look up line in label2line. I.e. line = label2line[label_w[i]].

# %%
def get_ipi_timecourses(label, verbose=False): # get idx
    line = label2line[label]
    if not np.isnan(line): 
        rsp = ipi_rsps[int(line - 1)]
        if rsp.shape[1] == 163:
            return np.concatenate([rsp, np.nan*np.zeros((len(ipi), 1))], axis=1)  # make sure there are 164 timesteps in response array
        else:
            return rsp
    else:
        if verbose:  print(f'No ipi responses for cell {label}')
        return None

def get_freq_timecourses(label, verbose=False): # get idx
    line = label2line[label]
    if not np.isnan(line): 
        rsp = freq_rsps[int(line - 1)]
        if rsp.shape[1] == 163:
            return np.concatenate([rsp, np.nan*np.zeros((len(freq), 1))], axis=1)  # make sure there are 164 timesteps in response array
        else:
            return rsp
    else:
        if verbose:  print(f'No freq responses for cell {label}')
        return None

# %%
def w2rgba(w_, w_min=-3, w_max=3):
    cmap = cm.get_cmap('PiYG')
    return cmap(w_/6 + .5)

# %% [markdown]
# Model emergence of tuning curve from upstream tuning via linear dynamical system

# %% [markdown]
# $$\tau \frac{dr_i}{dt} = -r_i + \sum_j W_{ij} x_j$$

# %% [markdown]
# Each target neuron (col in weight matrix) w/ corresponding tuning curve dataset gives distinct analysis to do. We take the tuning curve data for the target neuron, look up its upstream neighbors and their weights onto the target neuron, compute a model response using a linear dynamical system and the upstream responses, then recompute the tuning curve for the model responses.

# %%
# IPI tuning
DT = 1/FPS
TAU = .5
INRNS = np.argsort((np.abs(w) > 0).sum(axis=0))[::-1]
INRNS_PLOT = []  #INRNS

labels_up_total_all = {}
labels_up_valid_all = {}
labels_up_missing_all = {}

rsp_err_all = {}
tuning_err_all = {}

tuning_curves_data_all = {}
tuning_curves_model_all = {}

labels_no_tuning = []
labels_no_upstream = []

n_skipped = 0

for inrn in INRNS:
    
    label = labels_w[inrn]
    
    t = np.arange(164)/FPS

    if np.isnan(label2line[label]):
        print(f'No IPI tuning data for cell {label}')
        labels_no_tuning.append(label)
        rsp_err_all[label] = np.nan
        tuning_err_all[label] = np.nan
        n_skipped += 1
        continue
        
    # upstream inputs
    iup = w[:, inrn].nonzero()[0]  # idxs relative to w and labels_w
    w_up = w[iup, inrn]  # weights
    labels_up = labels_w[iup]  # labels
    lines_up = np.array([label2line[label_up] for label_up in labels_up])
    
    # subset of upstream inputs with tuning curve data (mask for previous 4 arrays)
    mvalid = ~np.isnan(lines_up)
    assert len(iup) == len(w_up) == len(labels_up) == len(lines_up)
    
    if np.sum(mvalid) == 0:
        print(f'No upstream IPI tuning data for cell {label}')
        labels_no_upstream.append(label)
        rsp_err_all[label] = np.nan
        tuning_err_all[label] = np.nan
        n_skipped += 1
        continue
 
    labels_up_valid = labels_up[mvalid]  # labels of upstream cells w/ IPI data
    labels_up_missing = labels_up[~mvalid]  # labels of upstream cells w/o IPI data
 
    labels_up_total_all[label] = labels_up.copy()
    labels_up_valid_all[label] = labels_up_valid.copy()
    labels_up_missing_all[label] = labels_up_missing.copy()
    
    # weights corresponding to valid upstream labels
    w_up_valid = w_up[mvalid]
    w_scale = np.nanstd(w_up_valid) if len(w_up_valid) >= 2 else 1
    w_up_valid /= w_scale
    
    # target neuron's true ipi time courses
    rsps_data = get_ipi_timecourses(label)
    rsps_data /= np.nanstd(rsps_data)  # z-score across time & stims

    # upstream neuron ipi time courses
    rsps_up_all = [get_ipi_timecourses(label_up) for label_up in labels_up_valid]
    
    # run simulation for each IPI
    rsps_model = np.nan * np.zeros((len(ipi), len(t)))  # one row per IPI
    for cipi, ipi_ in enumerate(ipi):
        # get array of upstream neuron activities for this IPI
        rsp_up = np.array([rsps_up[cipi, :] for rsps_up in rsps_up_all])
        assert rsp_up.shape == (len(labels_up_valid), len(t)) or len(rsp_up) == 0
        
        r = np.nan * np.zeros(len(t))
        
        r[0] = 0

        for ct, t_ in enumerate(t[1:], 1):
            dr = (DT/TAU) * (-r[ct-1] + w_up_valid@rsp_up[:, ct])
            r[ct] = r[ct-1] + dr
        
        rsps_model[cipi, :] = r.copy()
        
    rsps_model /= np.nanstd(rsps_model)  # z-score across time & stims
    
    rsp_err_all[label] = np.sqrt(np.nanmean((rsps_model - rsps_data)**2))
    
    # compute IPI tuning curves for data and model
    mtuning = (5 <= t) & (t < 13)
    
    rsp_tavg_data = np.array([rsp_data[mtuning].sum()*DT for rsp_data in rsps_data])
    rsp_tavg_model = np.array([rsp_model[mtuning].sum()*DT for rsp_model in rsps_model])
    
    tuning_curves_data_all[label] = rsp_tavg_data.copy()
    tuning_curves_model_all[label] = rsp_tavg_model.copy()
    
    tuning_err_all[label] = np.sqrt(np.mean((rsp_tavg_data - rsp_tavg_model)**2))
       
    # input currents for each IPI and true vs modeled output current for each IPI
    if inrn not in INRNS_PLOT:
        continue
        
    fig = plt.figure(figsize=(17, 6), tight_layout=True)
    ax1 = fig.add_subplot(2, 6, 1)
    axs = np.array([
        [ax1] + [fig.add_subplot(2, 6, i, sharex=ax1, sharey=ax1) for i in range(2, 6)] + [fig.add_subplot(2, 6, 6)],
        [fig.add_subplot(2, 6, i, sharex=ax1, sharey=ax1) for i in range(7, 12)] + [fig.add_subplot(2, 6, 12)],
    ])

    for cipi, (ax, ipi_) in enumerate(zip(axs[0, :-1], ipi)):  # loop over IPIs
        # plot all upstream responses (i.e. inputs) colored by weight
        rsp_up = np.array([rsps_up[cipi, :] for rsps_up in rsps_up_all])  # upstream responses at this IPI
        assert len(rsp_up) == len(w_up_valid)

        for rsp_up_, w_ in zip(rsp_up, w_up_valid):
            ax.plot(t, rsp_up_, c=w2rgba(w_))

        ax.set_facecolor((.8, .8, .8))
        ax.set_title(f'{inrn}: {label}\n{len(w_up)} upstream\n{len(labels_up_valid)} valid, {len(labels_up_missing)} missing \nIPI = {ipi_} ms')
    
    # true vs modeled target neuron response (for all IPIs)
    for cipi, (ax, ipi_) in enumerate(zip(axs[1, :-1], ipi)):
        ax.plot(t, rsps_data[cipi], c='k')
        ax.plot(t, rsps_model[cipi], c='b')

        ax.set_xlabel('Time (s)')
        
    axs[1, 0].legend(['Data', 'Model'])

    axs[0, -1].scatter(lines_up[mvalid], w_up[mvalid], c=[w2rgba(w_/w_scale) for w_ in w_up[mvalid]])
    axs[0, -1].scatter(np.repeat(35, (~mvalid).sum()), w_up[~mvalid], facecolors='none', edgecolors=[w2rgba(w_/w_scale) for w_ in w_up[~mvalid]])
    axs[0, -1].set_facecolor((.8, .8, .8))
    axs[0, -1].axhline(0, color='gray', ls='--')
    axs[0, -1].axvline(label2line[label], c='k')
    axs[0, -1].set_xlim(0, 36)
    axs[0, -1].grid()

    axs[0, -1].set_xlabel('Line')
    axs[0, -1].set_ylabel('Weight')
    axs[0, -1].set_title(f'Targ line:{int(round(label2line[label]))}\nInput lines:\n{sorted(np.unique([int(line_up) for line_up in lines_up if not np.isnan(line_up)]))}')
    
    axs[1, -1].plot(ipi, rsp_tavg_data, c='k')
    axs[1, -1].plot(ipi, rsp_tavg_model, c='b')
    axs[1, -1].axhline(0, color='gray', ls='--')
    axs[1, -1].set_xlabel('IPI (ms)')
    axs[1, -1].set_ylabel('Integral')
    axs[1, -1].set_title('Tuning curves')
# Out:
# No IPI tuning data for cell WV-WV-1_3
# No IPI tuning data for cell WV-WV-1_1
# No IPI tuning data for cell WV-WV-2_5
# No IPI tuning data for cell WV-WV-2_4
# No IPI tuning data for cell WV-WV-2_2
# No IPI tuning data for cell WV-WV-2_6
# No IPI tuning data for cell WV-WV-3_6
# No IPI tuning data for cell WV-WV-1_2
# No IPI tuning data for cell WV-WV-3_7
# No IPI tuning data for cell WV-WV-2_3
# No IPI tuning data for cell WV-WV-2_1
# No IPI tuning data for cell pC1al_L
# No IPI tuning data for cell pC2lb_L1
# No IPI tuning data for cell pMN1_L
# No IPI tuning data for cell vpoEN_R1
# No IPI tuning data for cell pC2lb_L2
# No IPI tuning data for cell A1_R1
# No IPI tuning data for cell pC2lb_R2
# No IPI tuning data for cell pC2lb_R1
# No IPI tuning data for cell vpoEN_L2
# No IPI tuning data for cell vpoEN_L1
# No IPI tuning data for cell GF_R
# No IPI tuning data for cell vpoEN_R2
# No IPI tuning data for cell pC1al_R
# No IPI tuning data for cell WV-WV-3_2
# No IPI tuning data for cell pMN2_L
# No IPI tuning data for cell pC1as_L
# No IPI tuning data for cell pC2la_L7
# No IPI tuning data for cell pC2lc_R1
# No IPI tuning data for cell B1-u_R31
# No IPI tuning data for cell A1_R2
# No IPI tuning data for cell pC2lb_R3
# No IPI tuning data for cell pC2lb_L3
# No IPI tuning data for cell GF_L
# No IPI tuning data for cell WV-WV-3_5
# No IPI tuning data for cell pC2lb_L4
# No IPI tuning data for cell A1_L2
# No IPI tuning data for cell B1-4_R2
# No IPI tuning data for cell pC2lb_R4
# No IPI tuning data for cell B1-u_R3
# No IPI tuning data for cell WV-WV-3_4
# No IPI tuning data for cell B1-u_L6
# No IPI tuning data for cell pC2la_L2
# No IPI tuning data for cell pC2la_L1
# No IPI tuning data for cell WV-WV-3_1
# No IPI tuning data for cell pMN2_R
# No IPI tuning data for cell A1_L3
# No IPI tuning data for cell B1-4_R6
# No IPI tuning data for cell pC2lb_R5
# No IPI tuning data for cell pC2la_L5
# No IPI tuning data for cell B1-u_L16
# No IPI tuning data for cell B1-u_R14
# No IPI tuning data for cell B1-u_L22
# No IPI tuning data for cell pC2la_R3
# No IPI tuning data for cell pC2med_L5
# No IPI tuning data for cell pC1as_R2
# No IPI tuning data for cell B1-u_R26
# No IPI tuning data for cell B1-u_L2
# No IPI tuning data for cell B1-u_L19
# No IPI tuning data for cell B1-u_R18
# No IPI tuning data for cell vpoIN_L1
# No IPI tuning data for cell WV-WV-3_9
# No IPI tuning data for cell pC2la_L4
# No IPI tuning data for cell WV-WV-3_3
# No IPI tuning data for cell pC2la_R4
# No IPI tuning data for cell B1-u_R1
# No IPI tuning data for cell B1-u_R20
# No IPI tuning data for cell vpoIN_L6
# No IPI tuning data for cell B1-4_R5
# No IPI tuning data for cell B1-u_L34
# No IPI tuning data for cell vpoIN_L7
# No IPI tuning data for cell pC2lc_R3
# No IPI tuning data for cell pC2la_R1
# No IPI tuning data for cell B1-4_L5
# No IPI tuning data for cell B1-u_L25
# No IPI tuning data for cell pC2la_L6
# No IPI tuning data for cell WV-WV-3_8
# No IPI tuning data for cell B1-u_R4
# No IPI tuning data for cell B1-u_R11
# No IPI tuning data for cell vpoIN_R2
# No IPI tuning data for cell vpoIN_L4
# No IPI tuning data for cell B1-4_L1
# No IPI tuning data for cell pC2med_R6
# No IPI tuning data for cell B1-u_R23
# No IPI tuning data for cell B1-u_L8
# No IPI tuning data for cell B1-u_L9
# No IPI tuning data for cell B1-4_R1
# No IPI tuning data for cell B1-4_R7
# No IPI tuning data for cell B1-u_R28
# No IPI tuning data for cell pC2la_R2
# No IPI tuning data for cell vpoIN_L2
# No IPI tuning data for cell pC2med_L7
# No IPI tuning data for cell pC2med_L2
# No IPI tuning data for cell B1-u_R7
# No IPI tuning data for cell B1-u_R21
# No IPI tuning data for cell B1-u_R10
# No IPI tuning data for cell B1-u_R22
# No IPI tuning data for cell pC2med_R2
# No IPI tuning data for cell pC2med_R1
# No IPI tuning data for cell B1-u_R8
# No IPI tuning data for cell B1-u_L12
# No IPI tuning data for cell B1-4_L2
# No IPI tuning data for cell B1-4_L4
# No IPI tuning data for cell B1-u_L17
# No IPI tuning data for cell B1-u_R27
# No IPI tuning data for cell pC2la_L3
# No IPI tuning data for cell vpoIN_R1
# No IPI tuning data for cell B1-u_L3
# No IPI tuning data for cell pC2med_L1
# No IPI tuning data for cell pC2med_R5
# No IPI tuning data for cell B1-u_R32
# No IPI tuning data for cell B1-u_L27
# No IPI tuning data for cell B1-u_R25
# No IPI tuning data for cell B1-4_R4
# No IPI tuning data for cell pC2med_R4
# No IPI tuning data for cell vpoIN_R3
# No IPI tuning data for cell B1-u_R9
# No IPI tuning data for cell B1-u_R19
# No IPI tuning data for cell pC2med_L3
# No IPI tuning data for cell pC1as_R1
# No IPI tuning data for cell B1-4_L6
# No IPI tuning data for cell vpoIN_L3
# No IPI tuning data for cell B1-u_L10
# No IPI tuning data for cell B1-u_L15
# No IPI tuning data for cell B1-u_L21
# No IPI tuning data for cell B1-u_R29
# No IPI tuning data for cell B1-u_L26
# No IPI tuning data for cell B1-4_R3
# No IPI tuning data for cell vpoIN_L8
# No IPI tuning data for cell B1-u_R24
# No IPI tuning data for cell vpoIN_L5
# No IPI tuning data for cell A1_L1
# No IPI tuning data for cell vpoIN_R6
# No IPI tuning data for cell B1-u_L23
# No IPI tuning data for cell B1-u_R12
# No IPI tuning data for cell B1-u_L24
# No IPI tuning data for cell B1-u_R6
# No IPI tuning data for cell B1-u_L7
# No IPI tuning data for cell B1-u_L32
# No IPI tuning data for cell pC2med_L6
# No IPI tuning data for cell 36007_R6
# No IPI tuning data for cell pC2med_L8
# No IPI tuning data for cell pC2lc_R2
# No IPI tuning data for cell B1-4_L7
# No IPI tuning data for cell B1-u_L31
# No IPI tuning data for cell B1-u_R15
# No IPI tuning data for cell B1-u_R17
# No IPI tuning data for cell 36007_R4
# No IPI tuning data for cell B1-u_L28
# No IPI tuning data for cell pC2med_R3
# No IPI tuning data for cell B1-u_L30
# No IPI tuning data for cell pC2ld_R
# No IPI tuning data for cell vpoIN_R4
# No IPI tuning data for cell pC2med_L4
# No IPI tuning data for cell B1-u_L1
# No IPI tuning data for cell 36007_R3
# No IPI tuning data for cell B1-u_L20
# No IPI tuning data for cell vpoIN_R5
# No IPI tuning data for cell B1-u_R2
# No IPI tuning data for cell B1-u_R30
# No IPI tuning data for cell B1-u_L4
# No IPI tuning data for cell B1-u_R5
# No IPI tuning data for cell 36007_R5
# No IPI tuning data for cell B1-u_R13
# No upstream IPI tuning data for cell 45858_R
# No IPI tuning data for cell B1-u_L11
# No IPI tuning data for cell 36007_R1
# No IPI tuning data for cell B1-u_L18
# No IPI tuning data for cell B1-u_L29
# No IPI tuning data for cell 36007_R2
# No IPI tuning data for cell B1-u_L5
# No IPI tuning data for cell B1-u_L33
# No IPI tuning data for cell B1-4_L3
# No IPI tuning data for cell 36007_L1
# No IPI tuning data for cell B1-u_L14
# No IPI tuning data for cell B1-u_R33
# No IPI tuning data for cell 36007_L3
# No IPI tuning data for cell B1-u_L13
# No IPI tuning data for cell 36007_L2
# No upstream IPI tuning data for cell 35996_L
# No IPI tuning data for cell B1-u_R16
# No upstream IPI tuning data for cell 23281_R13
# No upstream IPI tuning data for cell 38918_L
# No upstream IPI tuning data for cell B2_R2
# No upstream IPI tuning data for cell B2_L2
# No upstream IPI tuning data for cell 23281_R9
# No upstream IPI tuning data for cell 23281_L7

# %%
print(f'{len(tuning_curves_model_all)} valid tuning curve analyses')
print(f'{n_skipped} skipped')
fig, axs = plt.subplots(24, 8, figsize=(16, 48), tight_layout=True)
keys = list(tuning_curves_model_all.keys())

for key, ax in zip(keys, axs.flatten()):
    tuning_data = tuning_curves_data_all[key]
    tuning_model = tuning_curves_model_all[key]
    ax.plot(ipi, tuning_data, c='k')
    ax.plot(ipi, tuning_model, c='b')
    ax.axhline(0, ls='--', color='gray')

    ax.set_xlabel('IPI (ms)')
    ax.set_ylabel('Response Integral')
    
    ax.set_title(f'{key}\n{len(labels_up_total_all[key])} upstream\n({len(labels_up_valid_all[key])} valid, {len(labels_up_missing_all[key])} missed)')
    
fig.savefig('plots/ipi_tuning_all.pdf')
# Out:
# 306 valid tuning curve analyses
# 187 skipped

# %% [markdown]
# Save csv file summarizing which cells have tuning recorded and how many presynaptic partners have tuning recorded

# %%
df_summary_columns = [
    'LABEL', 'W_ROW_COL', 'HAS_LINE', 'LINE', 'HAS_IPI', 'HAS_FREQ',
    'N_PRE_TOTAL', 'N_PRE_EXC', 'N_PRE_INH', 'N_PRE_WITH_IPI', 'N_PRE_WITH_FREQ', 'N_PRE_WITHOUT_IPI', 'N_PRE_WITHOUT_FREQ',
    'ALL_PRE', 'PRE_WITH_IPI', 'PRE_WITH_FREQ', 'PRE_WITHOUT_IPI', 'PRE_WITHOUT_FREQ',
    'IPI_RESPONSE_ERROR', 'IPI_TUNING_ERROR'
]
df_summary_data = []

for cnrn, label in enumerate(labels_w):
    data_dict = {'LABEL': label, 'W_ROW_COL': cnrn}
    
    data_dict['HAS_IPI'] = (get_ipi_timecourses(label) is not None)
    data_dict['HAS_FREQ'] = (get_freq_timecourses(label) is not None)
    
    if not np.isnan(label2line[label]):
        data_dict['HAS_LINE'] = True
        data_dict['LINE'] = label2line[label]
    else:
        data_dict['HAS_LINE'] = False
        data_dict['LINE'] = np.nan
    
    inrns_pre = np.nonzero(np.abs(w[:, cnrn]) > 0)[0]
    labels_pre = labels_w[inrns_pre]
    
    data_dict['N_PRE_TOTAL'] = len(inrns_pre)
    data_dict['N_PRE_EXC'] = np.sum(w[:, cnrn] > 0)
    data_dict['N_PRE_INH'] = np.sum(w[:, cnrn] < 0)
    
    data_dict['ALL_PRE'] = '[' + ' '.join([label_pre for label_pre in labels_pre]) + ']'
    
    labels_pre_with_ipi = []
    labels_pre_with_freq = []
    
    labels_pre_without_ipi = []
    labels_pre_without_freq = []
    
    for label_pre in labels_pre:
        
        if get_ipi_timecourses(label_pre) is not None:
            labels_pre_with_ipi.append(label_pre)
        else:
            labels_pre_without_ipi.append(label_pre)
            
        if get_freq_timecourses(label_pre) is not None:
            labels_pre_with_freq.append(label_pre)
        else:
            labels_pre_without_freq.append(label_pre)
    
    data_dict['N_PRE_WITH_IPI'] = len(labels_pre_with_ipi)
    data_dict['N_PRE_WITH_FREQ'] = len(labels_pre_with_freq)
    
    data_dict['N_PRE_WITHOUT_IPI'] = len(labels_pre_without_ipi)
    data_dict['N_PRE_WITHOUT_FREQ'] = len(labels_pre_without_freq)
    
    data_dict['PRE_WITH_IPI'] = '[' + ' '.join([label_pre for label_pre in labels_pre_with_ipi]) + ']'
    data_dict['PRE_WITH_FREQ'] = '[' + ' '.join([label_pre for label_pre in labels_pre_with_freq]) + ']'
    
    data_dict['PRE_WITHOUT_IPI'] = '[' + ' '.join([label_pre for label_pre in labels_pre_without_ipi]) + ']'
    data_dict['PRE_WITHOUT_FREQ'] = '[' + ' '.join([label_pre for label_pre in labels_pre_without_freq]) + ']'
    
    data_dict['IPI_RESPONSE_ERROR'] = rsp_err_all[label]
    data_dict['IPI_TUNING_ERROR'] = tuning_err_all[label]
    df_summary_data.append(data_dict)
    
df_summary = pd.DataFrame(columns=df_summary_columns, data=df_summary_data).to_csv('data/simple/cell_summary_ipi.csv', index=False)
